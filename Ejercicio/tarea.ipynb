# %% [markdown]
# A ver si me pongo las pilas y dejo de ser inútil y hago que algo me salga bien esta semana

# %% [markdown]
# Procedimiento y línea de pensamiento
#
# Consigna:
# "Crear socket servidor y cliente súper sencillo lo más básico posible para 1 cliente (sin manejo de errores)" Maggie me dijo que no use IA, así que lo único que pienso usar es la documentación oficial de Python.
#
# -Me pasé casi 3 horas investigando/estudiando conceptos y escribiendo todo lo que se me vino a la cabeza sobre lo básico del challenge:
# 1) ¿Qué es un socket?
# 2) Sockets de Berkeley & API BSD
# 3) Funciones de API Socket
# 4) Flujo de Diagrama del protocolo TCP
# 5) Sockets: Dominio, tipo y protocolo
# 6) IP
# 7) IPv4
# 8) IPv6
# 9) Agotamiento de direcciones IPv4
# 10) Conjunto de protocolos de Internet
# 11) TCP, UDP, IP
# 12) Pila de protocolos y las 4 capas de abstracción: Enlace, Internet, Transporte, Aplicación
# 13) Relación de la pila/stack protocolar de Internet y el modelo OSI
# 14) TCP (CARACTERÍSTICAS)
# 15) TCP 3-Way-Handshake
# 16) Concurrencia
# 17) Multiplexión
# 18) UDP (CARACTERÍSTICAS)
# 19) Checksum
# 19) Multiplexión
# 20) Concurrencia
# 21) Hashing y seguridad
# 22) SSL
# 23) TLS
#
# Estos conceptos son antes de realizar el challenge, teniendo en cuenta que es lo que creí que necesitaba antes de iniciar el challenge, utilicé la guía "Andragogía toolkit" para determinar esto.
#
# Mucho énfasis en conceptos porque vi que lo que en teoría es mi fuerte, no lo fue. Reprobé así que trataré de entenderlo de la forma más profunda, pasando siempre de forma intuitiva y aplicable a casos ordinarios. Para los conceptos, utilicé Wikipedia y corroboré los conceptos con otras páginas distintas a DataCamp (a la cual en esta oportunidad no accedí ni una vez, sabiendo que ahí está el código que me solicitaron realizar como tarea).
#
# Luego de esta explicación, comienzo a redactar código, son las 3:03:38 / 6:00:00 cuando escribí esto. Más de la mitad del tiempo va destinado al apartado de livecoding. Debería ser capaz de hacerlo.
#
# Los enlaces a las referencias consultadas:
# - https://docs.python.org/3/library/socket.html
# - https://docs.python.org/3/howto/sockets.html

# %%
# Recordando la teoría para esta consigna, del lado del server [1 solo cliente]
# El server crea su socket (Directo)
# El server tiene que asociar la IP y el Puerto (Directo)
# El listen del server se activa para ir captando la solicitud de conexión por parte del cliente (1)
# El server "escucha" la petición y acepta al cliente 
# El server recibe mensaje del cliente

# Caso del server 
import socket

HOST = "127.0.0.1" # Se usa localhost
PORT = 6869 # Puerto designado

server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM) # Se crea la variable server_socket con el objeto de la clase socket (IPv4, TCP)
server_socket.bind((HOST,PORT)) # Se bindea la IP local y un puerto designado 
server_socket.listen() # Se permite la escucha
(client_conn, addr)= server_socket.accept() # "cliente_conn" = (El objeto: socket_cliente) & "addr" = (Las direcciones: (IP, PORT) )
with client_conn:
    print(f"Client connected: {addr}") # Indicando que si se conecta el objeto socket_cliente --> haga print referenciando las direcciones.
    while True:
        data = client_conn.recv(1024) # Se define la variable "data" donde se alojan los valores recibidos
        if not data: break # Luego de que reciba los datos, rompe el bucle forzadando algo similar a un .close
        print(f"Received {repr(data)} from {(addr)}") # Leyendo la descripción built-in de "repr" parece que emula el decode

# %%
# Recordando la teoría para esta consigna, del lado del cliente [1 solo cliente]
# El cliente crea su socket (Directo)
# El cliente trata de conectarse (En teoría el server_socket utiliza listen y accept)
# El listen del server_socket debería estar en un bucle para ir captando posibles peticiones de los clientes. 
# El cliente es aceptado y se conecta
# El cliente manda un mensaje

# Caso del cliente
import socket

HOST = "127.0.0.1" # Se usa localhost
PORT = 6869 # Puerto designado

with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as socket_cliente: # Se crea al socket_cliente(IPv4, TCP), viene a ser el "cliente_conn" del lado de mi servidor 
    socket_cliente.connect((HOST,PORT)) # Se indica para iniciar la conexión del socket_cliente = cliente_conn(server) asociado a (HOST, PORT) = "addr" del lado de mi servidor
    data = (b"Mensaje de confirmacion") # Por los errores que me saltaban sin "b" calculo que es para que traduzca a bytes mi texto en formato "str" [Un encode rápido]
    socket_cliente.sendall(data) # Por lo visto sí, porque cuando traté de darle tilde en "confirmación" me tiró el error "Non-ASCII character not allowed in bytes string literal"

# %% [markdown]
# Todo el código fue resuelto sin el uso de la IA y solo con la documentación de Python, me había quedado estancado pero con la ayuda de Huguito pude ver que eran principalmente errores de sintaxis y de comprensión del concepto del formateo de la "b" que básicamente hace un encode rápido.
#
# Me costó imaginar dónde colocar el bucle while, siendo que anteriormente se aplicaba ya en el .listen(), ahora como era 1 sola solicitud de conexión solo en el connect aplica para luego ya desloggearse.
#
# En total estuve +10 horas distribuidas en 3 días:
# 1) D1: Conceptos (3 Horas) & Código (2 Horas)
# 2) D2: Código (3 Horas)
# 3) D3: Código (2 Horas)
